# %% [markdown]
# # GPU Cost Analysis

# %%
from datasets import load_dataset

ds = load_dataset("allenai/WildChat-1M")

# %%
from pathlib import Path

import pandas as pd
import requests

path = Path("data/raw-lmsys-data.json")
# we use the latest data
url = "https://storage.googleapis.com/arena_external_data/public/clean_battle_20240814_public.json"

if not path.exists():
    response = requests.get(url)

    with path.open("wb") as file:
        file.write(response.content)

# load the JSON data from the local file
with path.open() as file:
    battles = pd.read_json(file).sort_values(ascending=True, by=["tstamp"])

# %%
from datetime import datetime

tses = [datetime.utcfromtimestamp(ts) for ts in battles.tstamp.tolist()]

# %%
battles["dt"] = tses

# %%
counts = battles.iloc[-300000:].groupby("model_a").count().sort_values("model_b").model_b

# %%
pop = counts / counts.sum()

# %%
new_df = counts.reset_index()

# %%
new_df
# Out:
#                              model_a  model_b
# 0                    gemma-1.1-7b-it       49
# 1             phi-3-mini-4k-instruct      396
# 2                         glm-4-0520     1224
# 3            phi-3-small-8k-instruct     1386
# 4             deepseek-coder-v2-0724     2109
# 5                 mistral-large-2402     2269
# 6                          command-r     2343
# 7                    yi-1.5-34b-chat     2386
# 8           nemotron-4-340b-instruct     2588
# 9                 gpt-3.5-turbo-0125     2743
# 10        mixtral-8x7b-instruct-v0.1     3305
# 11          claude-3-sonnet-20240229     3556
# 12                 deepseek-coder-v2     3663
# 13                reka-core-20240722     3719
# 14               reka-flash-20240722     3807
# 15                  yi-large-preview     3880
# 16                gpt-4-1106-preview     3883
# 17                          yi-large     3905
# 18                gpt-4-0125-preview     4017
# 19                        gpt-4-0613     4035
# 20          phi-3-medium-4k-instruct     4057
# 21                    command-r-plus     4090
# 22                reka-core-20240501     4257
# 23       mixtral-8x22b-instruct-v0.1     4341
# 24       reka-flash-preview-20240611     4586
# 25                 gpt-4o-2024-08-06     5147
# 26                qwen2-72b-instruct     5400
# 27                     gemma-2-2b-it     5488
# 28  phi-3-mini-4k-instruct-june-2024     5567
# 29                mistral-large-2407     5959
# 30                   athene-70b-0725     6035
# 31               llama-3-8b-instruct     6478
# 32             llama-3.1-8b-instruct     6601
# 33           claude-3-haiku-20240307     6754
# 34            llama-3.1-70b-instruct     7137
# 35              gemini-advanced-0514     7204
# 36                 chatgpt-4o-latest     7619
# 37            gpt-4-turbo-2024-04-09     7895
# 38              deepseek-v2-api-0628     8483
# 39         gemini-1.5-flash-api-0514     9158
# 40            claude-3-opus-20240229     9183
# 41           llama-3.1-405b-instruct     9940
# 42            gpt-4o-mini-2024-07-18     9947
# 43           gemini-1.5-pro-exp-0801    10502
# 44              llama-3-70b-instruct    10698
# 45                     gemma-2-9b-it    12273
# 46                    gemma-2-27b-it    13418
# 47           gemini-1.5-pro-api-0514    14354
# 48                 gpt-4o-2024-05-13    14876
# 49        claude-3-5-sonnet-20240620    17290

# %%
rows = []

for idx in range(3000):  # a bit more than one day
    rows.append(ds["train"][idx])

# %%
from collections import Counter

import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4")
user_counter = Counter()
turn_text_lengths = []

for row in rows:
    conversation = row["conversation"]
    hashed_ip = row["hashed_ip"]
    user_counter[hashed_ip] += len(conversation) // 2

    for turn in conversation:
        turn_text_lengths.append(len(encoding.encode(turn["content"])))

# %%
import numpy as np

np.mean(list(user_counter.values()))  # average number of Qs per day per user
# Out:
# 7.508445945945946

# %%
2 * np.mean(turn_text_lengths)  # average dialogue length (multiply by two for in + out)
# Out:
# 479.64409448818895

# %%
import pandas as pd

df = pd.read_csv("data/table.csv")
full_df = pd.read_csv("data/full-table.csv")

# %%
full_df[full_df.License == "Proprietary"].Votes.sum() / full_df.Votes.sum()
# Out:
# 0.6798251708171085

# %%
prop_df = full_df[full_df.License == "Proprietary"]

# %%
prop_df["Popularity"] = prop_df.Votes / prop_df.Votes.sum() * 100
# Out:
# /tmp/ipykernel_48789/179080760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prop_df['Popularity'] = prop_df.Votes / prop_df.Votes.sum() * 100

# %%
prop_df = prop_df.sort_values("Popularity", ascending=False).iloc[:25]

# %%
prop_df["PPM"] = [
    15.0 * 0.8 + 75.0 * 0.2,  # Claude 3 Opus
    3.0 * 0.8 + 15.0 * 0.2,  # Claude 3 Sonnet
    0.25 * 0.8 + 1.25 * 0.2,  # Claude 3 Haiku
    5.0 * 0.8 + 15.0 * 0.2,  # GPT-4-1106-preview (estimated)
    5.0 * 0.8 + 15.0 * 0.2,  # GPT-4-0125-preview (estimated)
    10.0 * 0.8 + 30.0 * 0.2,  # GPT-4-Turbo-2024-04-09
    4,  # GPT-4o-2024-05-13
    3.50 * 0.8 + 10.0 * 0.2,  # Gemini-1.5-Pro-001
    3.0 * 0.8 + 6.0 * 0.2,  # GPT-3.5-Turbo-0125
    None,  # Reka-Core-20240501 (not available)
    0.35 * 0.8 + 0.35 * 0.2,  # Gemini-1.5-Flash-001
    10.0 * 0.8 + 30.0 * 0.2,  # GPT-4-0314
    3.50 * 0.8 + 10.0 * 0.2,  # Gemini-1.5-Pro-Preview-0409
    3.50 * 0.8 + 10.0 * 0.2,  # Gemini Advanced App (2024-05-14)
    None,  # Yi-Large-preview (not available)
    3.0 * 0.8 + 15.0 * 0.2,  # Claude 3.5 Sonnet
    8.0 * 0.8 + 24.0 * 0.2,  # Claude-2.1
    None,  # Qwen-Max-0428 (not available)
    3.50 * 0.8 + 15.0 * 0.2,  # Gemini-1.5-Pro-Exp-0801
    0.3,  # GPT-4o-mini-2024-07-18
    4,  # ChatGPT-4o-latest (2024-08-08)
    0.25 * 0.8 + 1.25 * 0.2,  # Claude-Instant-1
    None,  # Reka-Flash-Preview-20240611 (not available)
    None,  # Yi-Large (not available)
    5.0 * 0.8 + 15.0 * 0.2,  # GPT-4o-2024-08-06
]

# %%
prop_df["Popularity"] = prop_df.Popularity / prop_df.Popularity.sum()

# %%
prop_df["cost weight"] = prop_df.PPM * prop_df.Popularity

# %%
prop_df.sort_values("cost weight", ascending=False)
# Out:
#     Rank                             Model  Arena_Score 95% CI     Votes  \
# 17    14                     Claude 3 Opus       1248.0  +3/-3  158077.0
# 13    10            GPT-4-Turbo-2024-04-09       1257.0  +2/-3   86648.0
# 36    35                        GPT-4-0314       1186.0  +3/-3   55962.0
# 16    14                GPT-4-1106-preview       1251.0  +3/-3   93540.0
# 31    28                   Claude 3 Sonnet       1201.0  +3/-2  113042.0
# 19    15                GPT-4-0125-preview       1245.0  +3/-3   86921.0
# 50    61                        Claude-2.1       1118.0  +4/-3   37685.0
# 10     8                Gemini-1.5-Pro-001       1260.0  +3/-2   72623.0
# 3      3                 GPT-4o-2024-05-13       1286.0  +3/-3   80741.0
# 5      5                 Claude 3.5 Sonnet       1271.0  +3/-3   51097.0
# 12    10       Gemini-1.5-Pro-Preview-0409       1257.0  +3/-3   55604.0
# 7      6  Gemini Advanced App (2024-05-14)       1267.0  +4/-3   52136.0
# 58    69                GPT-3.5-Turbo-0125       1106.0  +3/-3   68883.0
# 1      2           Gemini-1.5-Pro-Exp-0801       1298.0  +4/-4   23232.0
# 9      7                 GPT-4o-2024-08-06       1262.0  +5/-5   13703.0
# 0      1    ChatGPT-4o-latest (2024-08-08)       1317.0  +5/-5   20805.0
# 40    39                    Claude 3 Haiku       1178.0  +2/-2  111047.0
# 22    21              Gemini-1.5-Flash-001       1227.0  +3/-3   58361.0
# 53    65                  Claude-Instant-1       1111.0  +5/-4   20622.0
# 4      5            GPT-4o-mini-2024-07-18       1275.0  +5/-4   21621.0
#
#    Organization      License Knowledge_Cutoff  Popularity    PPM  cost weight
# 17    Anthropic  Proprietary           2023/8    0.032336  27.00     2.924139
# 13       OpenAI  Proprietary          2023/12    0.023633  14.00     0.831098
# 36       OpenAI  Proprietary           2021/9    0.015263  14.00     0.536768
# 16       OpenAI  Proprietary           2023/4    0.076538   7.00     0.448602
# 31    Anthropic  Proprietary           2023/8    0.184992   5.40     0.418215
# 19       OpenAI  Proprietary          2023/12    0.071122   7.00     0.416858
# 50    Anthropic  Proprietary          Unknown    0.030835  11.20     0.289169
# 10       Google  Proprietary          2023/11    0.059423   4.80     0.238826
# 3        OpenAI  Proprietary          2023/10    0.099099   4.00     0.221269
# 5     Anthropic  Proprietary           2024/4    0.041810   5.40     0.189040
# 12       Google  Proprietary          2023/11    0.045498   4.80     0.182858
# 7        Google  Proprietary           Online    0.042660   4.80     0.171453
# 58       OpenAI  Proprietary           2021/9    0.056363   3.60     0.169895
# 1        Google  Proprietary          2023/11    0.019009   5.80     0.092317
# 9        OpenAI  Proprietary          2023/10    0.011212   4.00     0.065717
# 0        OpenAI  Proprietary          2023/10    0.017024   4.00     0.057016
# 40    Anthropic  Proprietary           2023/8    0.090863   0.45     0.034236
# 22       Google  Proprietary          2023/11    0.047753   0.35     0.013994
# 53    Anthropic  Proprietary          Unknown    0.016874   0.45     0.006358
# 4        OpenAI  Proprietary          2023/10    0.017691   0.30     0.004444

# %%
prop_df.at[17, "Popularity"] /= 4
prop_df.at[31, "Popularity"] *= 2
prop_df.at[13, "Popularity"] /= 3
prop_df.at[36, "Popularity"] /= 3
prop_df.at[3, "Popularity"] *= 1.5

# %%
prop_df.at[31, "Popularity"] /= 1.5

# %%
prop_df.at[3, "PPM"] = 4
prop_df.at[4, "PPM"] = 0.3
prop_df.at[9, "PPM"] = 4
prop_df.at[0, "PPM"] = 4

# %%
prop_df = prop_df.dropna()

# %%
prop_df["Popularity"] = prop_df.Popularity / prop_df.Popularity.sum()

# %%
(prop_df.Popularity * prop_df.PPM).sum()
# Out:
# 5.289747645114814

# %% [markdown]
# prop_df.sort_values('Popularity', ascending=False)

# %%
df.sort_values("NPBillions")
# Out:
#     Rank                         Model  Arena_Score   95% CI    Votes  \
# 51   133                   Gemma-2b-it        799.0  +10/-12   2443.0
# 31   101               Gemma-1.1-2b-it       1020.0    +4/-6  11351.0
# 11    58                 Gemma-2-2b-it       1132.0    +5/-5  18780.0
# 36   114                   Gemma-2b-it        990.0    +9/-9   4924.0
# 20    69               Gemma-1.1-2b-it       1099.0    +9/-8   6658.0
# 47   128                FastChat-T5-3B        879.0   +9/-11   4993.0
# 28   101      Phi-3-Mini-128k-Instruct       1037.0    +5/-3  21592.0
# 37   119               Qwen1.5-4B-Chat        990.0    +9/-9   4924.0
# 42   123                   ChatGLM2-6B        928.0  +12/-10   4016.0
# 46   127                    ChatGLM-6B        894.0    +8/-7   6381.0
# 39   121                   ChatGLM3-6B        964.0    +6/-6   7038.0
# 41   123                   MPT-7B-Chat        932.0  +13/-16   1787.0
# 35   114                     Vicuna-7B       1005.0    +7/-8   7018.0
# 34   111      Mistral-7B-Instruct-v0.1       1008.0    +5/-5   9138.0
# 22    98               Zephyr-7b-alpha       1041.0  +12/-15   1815.0
# 32   111          StripedHyena-Nous-7B       1017.0    +8/-7   5267.0
# 27   101               Llama-2-7b-chat       1037.0    +5/-5  14558.0
# 26   100                   Gemma-7b-it       1037.0    +6/-6   9172.0
# 33   111              OLMo-7B-instruct       1015.0    +8/-8   6498.0
# 48   129       StableLM-Tuned-Alpha-7B        868.0   +10/-9   4305.0
# 15    59           Starling-LM-7B-beta       1119.0    +4/-4  16656.0
# 10    42    Meta-Llama-3.1-8b-Instruct       1168.0    +6/-6  16168.0
# 7     35                 Gemma-2-9b-it       1188.0    +4/-4  26448.0
# 45   127      OpenAssistant-Pythia-12B        901.0    +8/-6   5872.0
# 49   131                  Dolly-V2-12B        840.0  +13/-10   3337.0
# 9     39                Jamba-1.5-Mini       1170.0   +10/-7   3541.0
# 24   100                    Vicuna-13B       1042.0    +6/-4  19786.0
# 40   123            GPT4All-13B-Snoozy        956.0    +9/-7   4762.0
# 38   121                     Koala-13B        988.0    +6/-5   7803.0
# 50   131                     LLaMA-13B        822.0  +10/-13   3487.0
# 44   123                    Alpaca-13B        922.0   +8/-10   4936.0
# 19    67              Qwen1.5-14B-Chat       1109.0    +5/-4  18661.0
# 43   123              RWKV-4-Raven-14B        924.0  +12/-11   2707.0
# 29   101                 Qwen-14B-Chat       1035.0   +7/-10   5067.0
# 14    58      Phi-3-Medium-4k-Instruct       1123.0    +4/-4  23569.0
# 4     23                Gemma-2-27b-it       1218.0    +5/-4  30040.0
# 21    97                  MPT-30B-chat       1046.0  +12/-13   2649.0
# 13    58              Qwen1.5-32B-Chat       1127.0    +8/-7  22756.0
# 30   101                   Guanaco-33B       1032.0  +10/-11   3001.0
# 16    63                   Yi-34B-Chat       1111.0    +4/-5  15933.0
# 23   100        CodeLlama-34B-instruct       1043.0    +8/-5   7506.0
# 17    65    Mixtral-8x7b-Instruct-v0.1       1114.0    +0/-0  76039.0
# 1     12            Mistral-Large-2407       1250.0    +5/-5  14793.0
# 18    67             WizardLM-70B-v1.0       1106.0    +8/-7   8387.0
# 3     14   Meta-Llama-3.1-70b-Instruct       1247.0    +5/-5  17011.0
# 2     12                    Athene-70b       1250.0    +5/-5  13655.0
# 8     35            Qwen2-72B-Instruct       1187.0    +4/-3  35522.0
# 5     23               Jamba-1.5-Large       1213.0  +10/-10   3537.0
# 12    58    Zephyr-ORPO-141b-A35b-v0.1       1130.0    +6/-6  12774.0
# 25   100              falcon-180b-chat       1034.0  +14/-18   1326.0
# 6     25      Nemotron-4-340B-Instruct       1209.0    +4/-4  20659.0
# 0      6  Meta-Llama-3.1-405b-Instruct       1266.0    +4/-4  22312.0
#
#      Organization                  License Knowledge_Cutoff  NPBillions
# 51           Meta           Non-commercial           2023/2         2.0
# 31         Google            Gemma license           2024/2         2.0
# 11         Google            Gemma license           2024/7         2.0
# 36         Google            Gemma license           2024/2         2.0
# 20     AllenAI/UW      AI2 ImpACT Low-risk          2023/11         2.0
# 47       Tsinghua               Apache 2.0           2023/3         3.0
# 28      Microsoft                      MIT          2023/10         3.8
# 37         Google            Gemma license           2024/2         4.0
# 42       MosaicML               Apache-2.0           2023/5         6.0
# 46  OpenAssistant           Non-commercial           2023/4         6.0
# 39    UC Berkeley           Non-commercial           2023/4         6.0
# 41       Nomic AI           Non-commercial           2023/3         7.0
# 35          LMSYS        Llama 2 Community           2023/7         7.0
# 34        Mistral               Apache 2.0           2023/9         7.0
# 22    HuggingFace                      MIT          2023/10         7.0
# 32    Together AI               Apache 2.0          2023/12         7.0
# 27           Meta        Llama 2 Community           2023/7         7.0
# 26         Google            Gemma license           2024/2         7.0
# 33       Allen AI               Apache-2.0           2024/2         7.0
# 48          LMSYS          CC-BY-NC-SA-4.0           2023/4         7.0
# 15      Nexusflow               Apache-2.0           2024/3         7.0
# 10           Meta      Llama 3.1 Community          2023/12         8.0
# 7          Google            Gemma license           2024/6         9.0
# 45       Stanford               Apache 2.0           2023/3        12.0
# 49   Stability AI          CC-BY-NC-SA-4.0           2023/4        12.0
# 9       AI21 Labs               Jamba Open           2024/3        12.0
# 24          LMSYS        Llama 2 Community           2023/7        13.0
# 40       Tsinghua               Apache-2.0          2023/10        13.0
# 38        Alibaba          Qianwen LICENSE           2024/2        13.0
# 50     Databricks                      MIT           2023/4        13.0
# 44           RWKV           Non-commercial           2023/4        13.0
# 19        Alibaba          Qianwen LICENSE           2024/2        14.0
# 43       Tsinghua               Apache 2.0           2023/6        14.0
# 29        Alibaba          Qianwen LICENSE           2023/8        14.0
# 14      Microsoft                      MIT          2023/10        14.0
# 4          Google            Gemma license           2024/6        27.0
# 21       MosaicML          CC-BY-NC-SA-4.0           2023/6        30.0
# 13        Alibaba          Qianwen LICENSE           2024/2        32.0
# 30             UW           Non-commercial           2023/5        33.0
# 16          01 AI               Yi License           2023/6        34.0
# 23           Meta        Llama 2 Community           2023/7        34.0
# 17        Mistral               Apache 2.0          2023/12        56.0
# 1         Mistral         Mistral Research           2024/7        70.0
# 18      Microsoft        Llama 2 Community           2023/8        70.0
# 3            Meta      Llama 3.1 Community          2023/12        70.0
# 2       NexusFlow             CC-BY-NC-4.0           2024/7        70.0
# 8         Alibaba          Qianwen LICENSE           2024/6        72.0
# 5       AI21 Labs               Jamba Open           2024/3        94.0
# 12    HuggingFace               Apache 2.0           2024/4       141.0
# 25            TII  Falcon-180B TII License           2023/9       180.0
# 6          Nvidia        NVIDIA Open Model           2023/6       340.0
# 0            Meta      Llama 3.1 Community          2023/12       405.0

# %%
df = df[df.NPBillions < 100]

# %%
def weighted_median(values, weights):
    i = np.argsort(values).astype(int)
    c = np.cumsum(np.array(weights)[i])
    return values[i[np.searchsorted(c, 0.5 * c[-1])]]


weighted_median(df.NPBillions.astype(int).tolist(), (df.Votes / df.Votes.sum()).tolist())
# Out:
# 14

# %%
df["Popularity"] = df.Votes / df.Votes.sum()
# Out:
# /tmp/ipykernel_62343/2508006063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Popularity'] = df.Votes / df.Votes.sum()

# %%
df["NPRound"] = ((df.NPBillions.astype(int) + 10) / 10).astype(int) * 10
# Out:
# /tmp/ipykernel_62343/641119866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NPRound'] = ((df.NPBillions.astype(int) + 10) / 10).astype(int) * 10

# %%
df.groupby("NPRound").sum("weights")
# Out:
#          Rank  Arena_Score     Votes  NPBillions   weights  Popularity
# NPRound
# 10       2328      23167.0  211930.0       125.8  0.374245    0.374245
# 20       1244      11832.0  103528.0       157.0  0.182819    0.182819
# 30         23       1218.0   30040.0        27.0  0.053047    0.053047
# 40        419       5359.0   51845.0       163.0  0.091553    0.091553
# 60         65       1114.0   76039.0        56.0  0.134276    0.134276
# 80        140       6040.0   89368.0       352.0  0.157814    0.157814
# 100        23       1213.0    3537.0        94.0  0.006246    0.006246
